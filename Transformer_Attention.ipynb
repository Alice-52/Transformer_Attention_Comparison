# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/transformer_attention
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/transformer_attention
# ...

# %% [markdown]
# ### Замеры для таблички со сравнением
# #### seed = 42

# %%
# %%time
# Эксперимент с Single-Head Attention
import importlib
import src.train
importlib.reload(src.train)
from src.train import main

from src.config import Config

cfg = Config()
cfg.attention_type = 'single_head'
cfg.seed = 42

main(config=cfg)
# Out:
# Seed: 42
# Attention type: single_head
# Using device: cuda
# Trainable parameters: 4,105,476
# Epoch 01 | train_loss=0.6817 train_acc=0.7343 | val_loss=0.4262 val_acc=0.8472 val_f1=0.8464
# Epoch 02 | train_loss=0.4028 train_acc=0.8555 | val_loss=0.3499 val_acc=0.8777 val_f1=0.8763
# Epoch 03 | train_loss=0.3245 train_acc=0.8854 | val_loss=0.2984 val_acc=0.8965 val_f1=0.8960
# Test metrics:
# loss: 0.3063
# accuracy: 0.8953
# f1_macro: 0.8950
# CPU times: user 1min 41s, sys: 978 ms, total: 1min 42s
# Wall time: 1min 46s

# %%
# %%time
# Эксперимент с Multi-Head
import importlib
import src.train
importlib.reload(src.train)
from src.train import main

from src.config import Config

cfg = Config()
cfg.attention_type = 'multihead'
cfg.seed = 42

main(config=cfg)
# Out:
# Seed: 42
# Attention type: multihead
# Using device: cuda
# Trainable parameters: 4,105,476
# Epoch 01 | train_loss=0.6315 train_acc=0.7548 | val_loss=0.3862 val_acc=0.8620 val_f1=0.8619
# Epoch 02 | train_loss=0.3793 train_acc=0.8644 | val_loss=0.3397 val_acc=0.8803 val_f1=0.8788
# Epoch 03 | train_loss=0.3124 train_acc=0.8891 | val_loss=0.2894 val_acc=0.8978 val_f1=0.8971
# Test metrics:
# loss: 0.3002
# accuracy: 0.8946
# f1_macro: 0.8940
# CPU times: user 2min 4s, sys: 1.13 s, total: 2min 5s
# Wall time: 2min 8s

# %%
# %%time
# Эксперимент с Local Attention
import importlib
import src.train
importlib.reload(src.train)
from src.train import main

from src.config import Config

cfg = Config()
cfg.attention_type = 'local'
cfg.seed = 42

main(config=cfg)
# Out:
# Seed: 42
# Attention type: local
# Using device: cuda
# Trainable parameters: 4,105,476
# Epoch 01 | train_loss=0.6521 train_acc=0.7487 | val_loss=0.3991 val_acc=0.8591 val_f1=0.8586
# Epoch 02 | train_loss=0.3938 train_acc=0.8617 | val_loss=0.3418 val_acc=0.8787 val_f1=0.8778
# Epoch 03 | train_loss=0.3281 train_acc=0.8857 | val_loss=0.3065 val_acc=0.8943 val_f1=0.8935
# Test metrics:
# loss: 0.3202
# accuracy: 0.8908
# f1_macro: 0.8903
# CPU times: user 2min 6s, sys: 1.02 s, total: 2min 7s
# Wall time: 2min 10s

# %% [markdown]
# #### seed = 123

# %%
# %%time
# Эксперимент с Single-Head Attention
import importlib
import src.train
importlib.reload(src.train)
from src.train import main

from src.config import Config

cfg = Config()
cfg.attention_type = 'single_head'
cfg.seed = 123

main(config=cfg)
# Out:
# Seed: 123
# Attention type: single_head
# Using device: cuda
# Trainable parameters: 4,105,476
# Epoch 01 | train_loss=0.6732 train_acc=0.7368 | val_loss=0.4379 val_acc=0.8440 val_f1=0.8422
# Epoch 02 | train_loss=0.4010 train_acc=0.8562 | val_loss=0.3579 val_acc=0.8759 val_f1=0.8748
# Epoch 03 | train_loss=0.3231 train_acc=0.8852 | val_loss=0.3196 val_acc=0.8875 val_f1=0.8873
# Test metrics:
# loss: 0.3242
# accuracy: 0.8862
# f1_macro: 0.8864
# CPU times: user 1min 42s, sys: 948 ms, total: 1min 43s
# Wall time: 1min 47s

# %%
# %%time
# Эксперимент с Multi-Head
import importlib
import src.train
importlib.reload(src.train)
from src.train import main

from src.config import Config

cfg = Config()
cfg.attention_type = 'multihead'
cfg.seed = 123

main(config=cfg)
# Out:
# Seed: 123
# Attention type: multihead
# Using device: cuda
# Trainable parameters: 4,105,476
# Epoch 01 | train_loss=0.6174 train_acc=0.7616 | val_loss=0.4110 val_acc=0.8573 val_f1=0.8555
# Epoch 02 | train_loss=0.3783 train_acc=0.8657 | val_loss=0.3482 val_acc=0.8789 val_f1=0.8776
# Epoch 03 | train_loss=0.3162 train_acc=0.8876 | val_loss=0.3181 val_acc=0.8904 val_f1=0.8904
# Test metrics:
# loss: 0.3159
# accuracy: 0.8886
# f1_macro: 0.8888
# CPU times: user 2min 3s, sys: 1.07 s, total: 2min 4s
# Wall time: 2min 7s

# %%
# %%time
# Эксперимент с Local Attention
import importlib
import src.train
importlib.reload(src.train)
from src.train import main

from src.config import Config

cfg = Config()
cfg.attention_type = 'local'
cfg.seed = 123

main(config=cfg)
# Out:
# Seed: 123
# Attention type: local
# Using device: cuda
# Trainable parameters: 4,105,476
# Epoch 01 | train_loss=0.6376 train_acc=0.7548 | val_loss=0.4299 val_acc=0.8549 val_f1=0.8534
# Epoch 02 | train_loss=0.3924 train_acc=0.8620 | val_loss=0.3526 val_acc=0.8762 val_f1=0.8750
# Epoch 03 | train_loss=0.3276 train_acc=0.8853 | val_loss=0.3248 val_acc=0.8884 val_f1=0.8879
# Test metrics:
# loss: 0.3283
# accuracy: 0.8849
# f1_macro: 0.8847
# CPU times: user 2min 5s, sys: 1.01 s, total: 2min 6s
# Wall time: 2min 9s

# %% [markdown]
# #### seed = 777

# %%
# %%time
# Эксперимент с Single-Head Attention
import importlib
import src.train
importlib.reload(src.train)
from src.train import main

from src.config import Config

cfg = Config()
cfg.attention_type = 'single_head'
cfg.seed = 777

main(config=cfg)
# Out:
# Seed: 777
# Attention type: single_head
# Using device: cuda
# Trainable parameters: 4,105,476
# Epoch 01 | train_loss=0.6846 train_acc=0.7305 | val_loss=0.4205 val_acc=0.8481 val_f1=0.8486
# Epoch 02 | train_loss=0.4068 train_acc=0.8535 | val_loss=0.3377 val_acc=0.8816 val_f1=0.8812
# Epoch 03 | train_loss=0.3306 train_acc=0.8827 | val_loss=0.2977 val_acc=0.8958 val_f1=0.8956
# Test metrics:
# loss: 0.3093
# accuracy: 0.8925
# f1_macro: 0.8922
# CPU times: user 1min 40s, sys: 841 ms, total: 1min 41s
# Wall time: 1min 44s

# %%
# %%time
# Эксперимент с Multi-Head
import importlib
import src.train
importlib.reload(src.train)
from src.train import main

from src.config import Config

cfg = Config()
cfg.attention_type = 'multihead'
cfg.seed = 777

main(config=cfg)
# Out:
# Seed: 777
# Attention type: multihead
# Using device: cuda
# Trainable parameters: 4,105,476
# Epoch 01 | train_loss=0.6306 train_acc=0.7541 | val_loss=0.3982 val_acc=0.8582 val_f1=0.8576
# Epoch 02 | train_loss=0.3852 train_acc=0.8634 | val_loss=0.3290 val_acc=0.8831 val_f1=0.8828
# Epoch 03 | train_loss=0.3222 train_acc=0.8861 | val_loss=0.3022 val_acc=0.8958 val_f1=0.8958
# Test metrics:
# loss: 0.3079
# accuracy: 0.8920
# f1_macro: 0.8919
# CPU times: user 2min 4s, sys: 1.01 s, total: 2min 5s
# Wall time: 2min 8s

# %%
# %%time
# Эксперимент с Local Attention
import importlib
import src.train
importlib.reload(src.train)
from src.train import main

from src.config import Config

cfg = Config()
cfg.attention_type = 'local'
cfg.seed = 777

main(config=cfg)
# Out:
# Seed: 777
# Attention type: local
# Using device: cuda
# Trainable parameters: 4,105,476
# Epoch 01 | train_loss=0.6472 train_acc=0.7488 | val_loss=0.4096 val_acc=0.8555 val_f1=0.8550
# Epoch 02 | train_loss=0.3964 train_acc=0.8599 | val_loss=0.3453 val_acc=0.8807 val_f1=0.8801
# Epoch 03 | train_loss=0.3334 train_acc=0.8834 | val_loss=0.3137 val_acc=0.8912 val_f1=0.8910
# Test metrics:
# loss: 0.3230
# accuracy: 0.8884
# f1_macro: 0.8881
# CPU times: user 2min 5s, sys: 1.02 s, total: 2min 6s
# Wall time: 2min 9s
