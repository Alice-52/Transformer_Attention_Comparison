# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content
# !rm -rf /content/transformer_attention
# !cp -r "/content/drive/MyDrive/transformer_attention" /content/
# %cd /content/transformer_attention
# !pip install -r requirements.txt
# Out:
# /content
# /content/transformer_attention
# ...

# %%
# !python -m src.experiment --attention_types single_head multihead local additive --seeds 42 123 777
# Out:
# ...
# Running attention_type=single_head seed=42
# Using device: cuda
# ...
# Trainable parameters: 4,105,476
# Epoch 01 | train_loss=0.6817 train_acc=0.7343 | val_loss=0.4262 val_acc=0.8472 val_f1=0.8464 | time=24.8s
# Epoch 02 | train_loss=0.4028 train_acc=0.8555 | val_loss=0.3499 val_acc=0.8777 val_f1=0.8763 | time=24.1s
# Epoch 03 | train_loss=0.3245 train_acc=0.8854 | val_loss=0.2984 val_acc=0.8965 val_f1=0.8960 | time=24.5s
#
# Test metrics:
# loss: 0.3063
# accuracy: 0.8953
# f1_macro: 0.8950
#
# ...
# Running attention_type=single_head seed=123
# Using device: cuda
# Trainable parameters: 4,105,476
# Epoch 01 | train_loss=0.6732 train_acc=0.7368 | val_loss=0.4379 val_acc=0.8440 val_f1=0.8422 | time=25.1s
# Epoch 02 | train_loss=0.4010 train_acc=0.8562 | val_loss=0.3579 val_acc=0.8759 val_f1=0.8748 | time=25.3s
# Epoch 03 | train_loss=0.3231 train_acc=0.8852 | val_loss=0.3196 val_acc=0.8875 val_f1=0.8873 | time=25.1s
#
# Test metrics:
# loss: 0.3242
# accuracy: 0.8862
# f1_macro: 0.8864
#
# ...
